# %% [markdown]
# <a href="https://colab.research.google.com/github/petyaslavkova/Bachelorarbeit/blob/main/EvaluationExperiment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
# !git clone https://github.com/KostasTok/Simpsons-Face-Detector.git
# Out:
# Cloning into 'Simpsons-Face-Detector'...
# remote: Enumerating objects: 46, done.
# remote: Total 46 (delta 0), reused 0 (delta 0), pack-reused 46
# Unpacking objects: 100% (46/46), done.

# %%
import os
from pathlib import Path
# %cd /content/Simpsons-Face-Detector/
IMAGES = Path('/content/Simpsons-Face-Detector/images')
os.makedirs(IMAGES, exist_ok = True)
# Out:
# /content/Simpsons-Face-Detector

# %%
def create_dataset_simpson_faces(download_dir):

  # %cd /content/Simpsons-Face-Detector/images

  # !unzip -q results_cycleGan.zip
  # !rm -rf results_cycleGan.zip


create_dataset_simpson_faces(IMAGES)
# Out:
# /content/Simpsons-Face-Detector/images
# unzip:  cannot find or open results_cycleGan.zip, results_cycleGan.zip.zip or results_cycleGan.zip.ZIP.

# %%
# %cd /content/Simpsons-Face-Detector/

import face_detector as fd
import os
from get_faces_help import (Reporter, get_video_paths) 
import imageio
import numpy as np
from PIL import Image
# Out:
# /content/Simpsons-Face-Detector

# %%
import glob
from PIL import Image
from numpy import*

# %cd /content/Simpsons-Face-Detector/images

temp=asarray(Image.open('epoch020_fake_B.png'))
for j in temp:
    new_temp = asarray([[i[0],i[1]] for i in j]) 

# Processes the image and returns:
# 1) A simplified version of it that maintains only
#    the colors that appear on a face (Black,Yellow,White)
# 2) An image with only the detected faces 

_, _, extra1, extra2 = fd.find_face(temp ,True)

import matplotlib.pyplot as plt
fig, (ax1,ax2,ax3) = plt.subplots(ncols=3, nrows=1, figsize = (16,12))
ax1.imshow(temp)
ax1.get_xaxis().set_visible(False)
ax1.get_yaxis().set_visible(False)
ax1.set_title('Original')
ax2.imshow(extra1)
ax2.get_xaxis().set_visible(False)
ax2.get_yaxis().set_visible(False)
ax2.set_title('Simplified')
ax3.imshow(extra2)
ax3.get_xaxis().set_visible(False)
ax3.get_yaxis().set_visible(False)
ax3.set_title('Faces')
# Out:
# /content/Simpsons-Face-Detector/images
# Text(0.5, 1.0, 'Faces')
